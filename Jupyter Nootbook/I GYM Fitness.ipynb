# %%
Image(url='https://medlux.net.ua/wp-content/uploads/2021/11/sport-protyv-depressy.jpg', width=1000)
# Out:
# <img src="https://medlux.net.ua/wp-content/uploads/2021/11/sport-protyv-depressy.jpg" width="1000"/>

# %% [markdown]
# ## 🔹 Importing required libraries

# %%
from IPython.display import Image

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🔹 Load the dataset using the pandas read function

# %%
df = pd.read_csv('dailyActivity_merged.csv')
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [markdown]
# ## 🔹 get the important column by creat new df

# %%
cols = ['Id','ActivityDate','TotalSteps','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes','Calories']
df = df[cols]

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  4/12/2016       13162                 25
# 1    1503960366  4/13/2016       10735                 21
# 2    1503960366  4/14/2016       10460                 30
# 3    1503960366  4/15/2016        9762                 29
# 4    1503960366  4/16/2016       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391   5/8/2016       10686                 17
# 936  8877689391   5/9/2016       20226                 73
# 937  8877689391  5/10/2016       10733                 18
# 938  8877689391  5/11/2016       21420                 88
# 939  8877689391  5/12/2016        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
#rename the column
df.rename(columns={'ActivityDate': 'date'}, inplace=True)
# Out:
# C:\Users\ZMZM\AppData\Local\Temp\ipykernel_10644\3392897770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'ActivityDate': 'date'}, inplace=True)

# %% [markdown]
# ## 🔹 Adding new column to df

# %%
df['TotalMinutes'] = df['VeryActiveMinutes'] + df['FairlyActiveMinutes'] + df['LightlyActiveMinutes'] + df['SedentaryMinutes']
# Out:
# C:\Users\ZMZM\AppData\Local\Temp\ipykernel_10644\26864058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalMinutes'] = df['VeryActiveMinutes'] + df['FairlyActiveMinutes'] + df['LightlyActiveMinutes'] + df['SedentaryMinutes']

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  4/12/2016       13162                 25
# 1    1503960366  4/13/2016       10735                 21
# 2    1503960366  4/14/2016       10460                 30
# 3    1503960366  4/15/2016        9762                 29
# 4    1503960366  4/16/2016       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391   5/8/2016       10686                 17
# 936  8877689391   5/9/2016       20226                 73
# 937  8877689391  5/10/2016       10733                 18
# 938  8877689391  5/11/2016       21420                 88
# 939  8877689391  5/12/2016        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df['TotalHours'] = (df['TotalMinutes'] / 60).round()
# Out:
# C:\Users\ZMZM\AppData\Local\Temp\ipykernel_10644\1645713518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalHours'] = (df['TotalMinutes'] / 60).round()

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  4/12/2016       13162                 25
# 1    1503960366  4/13/2016       10735                 21
# 2    1503960366  4/14/2016       10460                 30
# 3    1503960366  4/15/2016        9762                 29
# 4    1503960366  4/16/2016       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391   5/8/2016       10686                 17
# 936  8877689391   5/9/2016       20226                 73
# 937  8877689391  5/10/2016       10733                 18
# 938  8877689391  5/11/2016       21420                 88
# 939  8877689391  5/12/2016        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
import datetime as dt
df['DayOfWeek'] = df['date'].dt.day_name()
# Out:
# C:\Users\ZMZM\AppData\Local\Temp\ipykernel_10644\494334488.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'] = df['date'].dt.day_name()

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-04-12       13162                 25
# 1    1503960366 2016-04-13       10735                 21
# 2    1503960366 2016-04-14       10460                 30
# 3    1503960366 2016-04-15        9762                 29
# 4    1503960366 2016-04-16       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391 2016-05-08       10686                 17
# 936  8877689391 2016-05-09       20226                 73
# 937  8877689391 2016-05-10       10733                 18
# 938  8877689391 2016-05-11       21420                 88
# 939  8877689391 2016-05-12        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %% [markdown]
# ## 🔹 Set the dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   date                  940 non-null    object
#  2   TotalSteps            940 non-null    int64
#  3   VeryActiveMinutes     940 non-null    int64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   Calories              940 non-null    int64
#  8   TotalMinutes          940 non-null    int64
#  9   TotalHours            940 non-null    float64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 73.6+ KB

# %% [markdown]
# ## 🔹 Convert column (date) from object datatype ➡ datatime

# %%
df.date = pd.to_datetime(df.date)
# Out:
# C:\Users\ZMZM\AppData\Local\Temp\ipykernel_10644\3783387829.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.date = pd.to_datetime(df.date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   date                  940 non-null    datetime64[ns]
#  2   TotalSteps            940 non-null    int64
#  3   VeryActiveMinutes     940 non-null    int64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   Calories              940 non-null    int64
#  8   TotalMinutes          940 non-null    int64
#  9   TotalHours            940 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(8)
# memory usage: 73.6 KB

# %% [markdown]
# ## 🔹 Inspecting Data

# %%
df.isnull().sum()
# Out:
# Id                      0
# date                    0
# TotalSteps              0
# VeryActiveMinutes       0
# FairlyActiveMinutes     0
# LightlyActiveMinutes    0
# SedentaryMinutes        0
# Calories                0
# TotalMinutes            0
# TotalHours              0
# DayOfWeek               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[['TotalSteps','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes','Calories','TotalMinutes','TotalHours']].describe().round(2)
# Out:
#        TotalSteps  VeryActiveMinutes  FairlyActiveMinutes  \
# count      940.00             940.00               940.00
# mean      7637.91              21.16                13.56
# std       5087.15              32.84                19.99
# min          0.00               0.00                 0.00
# 25%       3789.75               0.00                 0.00
# 50%       7405.50               4.00                 6.00
# 75%      10727.00              32.00                19.00
# max      36019.00             210.00               143.00
#
#        LightlyActiveMinutes  SedentaryMinutes  Calories  TotalMinutes  \
# count                940.00            940.00    940.00        940.00
# mean                 192.81            991.21   2303.61       1218.75
# std                  109.17            301.27    718.17        265.93
# min                    0.00              0.00      0.00          2.00
# 25%                  127.00            729.75   1828.50        989.75
# ...

# %% [markdown]
# ## 🔹 Exploring & Analysis Data

# %%
plt.figure(figsize=((6,4)))
plt.hist(df.DayOfWeek , bins=7, color='DarkCyan', width = 0.6)
plt.grid(True)

plt.title('Freq by Day of week', color='black')
plt.show()

# %%
plt.figure(figsize=((8,6)))
plt.scatter(df.TotalSteps, df.Calories, c=df.Calories)

median_steps = 7405
median_calories =  2134

plt.axhline(median_calories, color='blue', label='median of calories')
plt.axvline(median_steps, color='red', label='median of steps')

plt.xlabel="steps"
plt.ylabel="Calories"

plt.title="Calories by total steps"
plt.legend()
plt.show()

# %%
plt.figure(figsize=((8,6)))
plt.scatter(df.TotalHours, df.Calories, c=df.Calories)

median_hours = 24
median_calories =  2134

plt.axhline(median_calories, color='blue', label='median of calories')
plt.axvline(median_hours, color='red', label='median of hours')

plt.xlabel="hours"
plt.ylabel="Calories"

plt.title="Calories by total hours"
plt.legend()
plt.show()

# %%
VeryActiveMinutes = df.VeryActiveMinutes.sum()
FairlyActiveMinutes = df.FairlyActiveMinutes.sum()
LightlyActiveMinutes = df.LightlyActiveMinutes.sum()
SedentaryMinutes = df.SedentaryMinutes.sum()

minutes = [VeryActiveMinutes, FairlyActiveMinutes, LightlyActiveMinutes, SedentaryMinutes]
labels = ['VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes']

plt.pie(minutes, labels=labels, autopct= '%1.1f%%', explode = [0,0,0,0.1])
plt.show()

# %% [markdown]
# ##### ✅ We conclude from the above that the majority of users use the application to track daily activities, “Sedentary Minutes” at a rate of 81.3%.
# ##### ✅ We also conclude that users prefer to track their activities during the days of the week (Tuesday, Wednesday, and Thursday).
#
# ##### How can we improve the company's marketing strategy based on the perceptions and conclusions we made:
#
# ##### 1- The company’s marketing team can encourage users to educate them and provide them with knowledge about the benefits of fitness and sports activities.
# ##### 2- Suggest exercises to users, such as a simple exercise for 10 minutes per week.
# ##### 3- Do more distance training on the weekends.
# ##### 4- Providing them with information about the rate of burning calories for each activity so that they are motivated to do these activities.

# %% [markdown]
# # Regards, Tariq Ibrahim 🤞
